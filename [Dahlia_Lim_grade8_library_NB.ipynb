# %% [markdown]
# <a href="https://colab.research.google.com/github/PhilULim/8-Dahlia-Lim-grade8-library-Repo-Example-Rosal-DeLeon-grade8-library-Repo/blob/main/%5BDahlia_Lim_grade8_library_NB.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
import json
url = "https://raw.githubusercontent.com/PhilULim/8-Dahlia-Lim-grade8-library-Repo-Example-Rosal-DeLeon-grade8-library-Repo/refs/heads/main/books.json"
response = requests.get(url)
books = response.json()
print(books)
# Out:
# {'books': [{'id': 2001, 'title': 'Introduction to Python', 'author': 'Juan Dela Cruz', 'details': {'copies': 5, 'available': 3}}, {'id': 2002, 'title': 'Data Structures Basics', 'author': 'Maria Santos', 'details': {'copies': 4, 'available': 2}}, {'id': 2003, 'title': 'Web Development Essentials', 'author': 'Carlos Reyes', 'details': {'copies': 6, 'available': 6}}]}

# %%
# !pip install firebase-admin

# %%
import firebase_admin
from firebase_admin import credentials, db
cred = credentials.Certificate("/content/firebase_key1.json")
firebase_admin.initialize_app(cred, {
 "databaseURL": "https://dahlia-lim-grade8-library-db-default-rtdb.asia-southeast1.firebasedatabase.app/"
})
print("Firebase connected successfully!")
# Out:
# Firebase connected successfully!

# %%
import requests
import json

data = books
print("JSON file loaded")
ref = db.reference("books")
for book in data["books"]:
  ref.child(str(book["id"])).set(book)
print("Data uploaded successfully!")
# Out:
# JSON file loaded
# Data uploaded successfully!

# %%
books_data = ref.get()
for key, book in books_data.items():
  print(book)
# Out:
# {'author': 'Juan Dela Cruz', 'details': {'available': 3, 'copies': 5}, 'id': 2001, 'title': 'Introduction to Python'}
# {'author': 'Maria Santos', 'details': {'available': 2, 'copies': 4}, 'id': 2002, 'title': 'Data Structures Basics'}
# {'author': 'Carlos Reyes', 'details': {'available': 6, 'copies': 6}, 'id': 2003, 'title': 'Web Development Essentials'}

# %%
books_data = ref.get()

for key, book in books_data.items():
  title = book["title"]
  print (title)
# Out:
# 'Introduction to Python'
# 'Data Structures Basics'
# 'Web Development Essentials'

# %%
books_data = ref.get()

for key, book in books_data.items():
  details = book["details"]
  available_data = details["available"]
  print(book["title"],"| Available copies:", available_data)
# Out:
# Introduction to Python | Available copies: 3
# Data Structures Basics | Available copies: 2
# Web Development Essentials | Available copies: 6

# %%
books_data = ref.get()

total_books = 0

for key, book in books_data.items():
  details = book["details"]
  copies = details["copies"]
  print(book["title"],"| Copies:", copies)
  total_books += copies
print("Total number of books in library:", total_books)
# Out:
# Introduction to Python | Copies: 5
# Data Structures Basics | Copies: 4
# Web Development Essentials | Copies: 6
# Total number of books in library: 15
